# %%
import gym
from libs.Environments.CircularOrbitEnv import *

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.env_checker import check_env

# %%
env = CircularOrbitEnv(
    satellite_num=500
)

check_env(env)

model = PPO("MlpPolicy", env, verbose=1,tensorboard_log="satellite")
model.learn(total_timesteps=1000000)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to satellite/PPO_2
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.12      |
# |    ep_rew_mean     | -2.07e+03 |
# | time/              |           |
# |    fps             | 729       |
# |    iterations      | 1         |
# |    time_elapsed    | 2         |
# |    total_timesteps | 2048      |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.08         |
# |    ep_rew_mean          | -2.79e+03    |
# | time/                   |              |
# |    fps                  | 503          |
# |    iterations           | 2            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0012877582 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.97e+06     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00281     |
# |    value_loss           | 1.85e+07     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.05       |
# |    ep_rew_mean          | -2.25e+03  |
# | time/                   |            |
# |    fps                  | 457        |
# |    iterations           | 3          |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00155923 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.77      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.87e+06   |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00311   |
# |    value_loss           | 1.59e+07   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.06         |
# |    ep_rew_mean          | -2.7e+03     |
# | time/                   |              |
# |    fps                  | 436          |
# |    iterations           | 4            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0010191838 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.63e+06     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0023      |
# |    value_loss           | 1.81e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.06         |
# |    ep_rew_mean          | -2.7e+03     |
# | time/                   |              |
# |    fps                  | 425          |
# |    iterations           | 5            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0008359682 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.41e+07     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00175     |
# |    value_loss           | 1.76e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.09         |
# |    ep_rew_mean          | -2.52e+03    |
# | time/                   |              |
# |    fps                  | 418          |
# |    iterations           | 6            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0007085053 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.83e+06     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00155     |
# |    value_loss           | 1.64e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.06         |
# |    ep_rew_mean          | -2.25e+03    |
# | time/                   |              |
# |    fps                  | 413          |
# |    iterations           | 7            |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0016072472 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02e+07     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00313     |
# |    value_loss           | 1.64e+07     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.06       |
# |    ep_rew_mean          | -2.25e+03  |
# | time/                   |            |
# |    fps                  | 409        |
# |    iterations           | 8          |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00334315 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.74      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.81e+06   |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00543   |
# |    value_loss           | 1.59e+07   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.07         |
# |    ep_rew_mean          | -2.34e+03    |
# | time/                   |              |
# |    fps                  | 407          |
# |    iterations           | 9            |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0025398303 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.72        |
# |    explained_variance   | 2.98e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.62e+06     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00512     |
# |    value_loss           | 1.66e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.05         |
# |    ep_rew_mean          | -2.97e+03    |
# | time/                   |              |
# |    fps                  | 404          |
# |    iterations           | 10           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0026974443 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.7         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.43e+06     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00392     |
# |    value_loss           | 1.48e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.04         |
# |    ep_rew_mean          | -2.62e+03    |
# | time/                   |              |
# |    fps                  | 403          |
# |    iterations           | 11           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0016533193 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.68        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.3e+06      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00298     |
# |    value_loss           | 1.61e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.08         |
# |    ep_rew_mean          | -2.16e+03    |
# | time/                   |              |
# |    fps                  | 401          |
# |    iterations           | 12           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0012499501 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.67        |
# |    explained_variance   | 2.98e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.28e+06     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0025      |
# |    value_loss           | 1.69e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.08         |
# |    ep_rew_mean          | -2.79e+03    |
# | time/                   |              |
# |    fps                  | 400          |
# |    iterations           | 13           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0031411934 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.65        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.88e+06     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00553     |
# |    value_loss           | 1.65e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.03         |
# |    ep_rew_mean          | -2.35e+03    |
# | time/                   |              |
# |    fps                  | 399          |
# |    iterations           | 14           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0008469176 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.62        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02e+07     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00201     |
# |    value_loss           | 1.5e+07      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.1          |
# |    ep_rew_mean          | -2.25e+03    |
# | time/                   |              |
# |    fps                  | 398          |
# |    iterations           | 15           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0019797808 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.6         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.01e+06     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00403     |
# |    value_loss           | 1.54e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.07         |
# |    ep_rew_mean          | -1.89e+03    |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 16           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0036742857 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.57        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.37e+06     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00453     |
# |    value_loss           | 1.53e+07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.07        |
# |    ep_rew_mean          | -2.79e+03   |
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 17          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.002180475 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.7e+06     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00273    |
# |    value_loss           | 1.44e+07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.07         |
# |    ep_rew_mean          | -2.61e+03    |
# | time/                   |              |
# |    fps                  | 396          |
# |    iterations           | 18           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0022509638 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.5         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.69e+06     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00285     |
# |    value_loss           | 1.43e+07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.06        |
# |    ep_rew_mean          | -2.61e+03   |
# | time/                   |             |
# |    fps                  | 395         |
# |    iterations           | 19          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.002831405 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.46       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.43e+06    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00446    |
# |    value_loss           | 1.53e+07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.05         |
# |    ep_rew_mean          | -2.25e+03    |
# | time/                   |              |
# |    fps                  | 395          |
# |    iterations           | 20           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0034123957 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.4         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13e+07     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00314     |
# |    value_loss           | 1.55e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.07         |
# |    ep_rew_mean          | -2.07e+03    |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 21           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0010901808 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.37        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.32e+07     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00191     |
# |    value_loss           | 1.5e+07      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.14         |
# |    ep_rew_mean          | -2.43e+03    |
# | time/                   |              |
# |    fps                  | 393          |
# |    iterations           | 22           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0009679019 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.36        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.08e+07     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 1.53e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.13          |
# |    ep_rew_mean          | -2.34e+03     |
# | time/                   |               |
# |    fps                  | 391           |
# |    iterations           | 23            |
# |    time_elapsed         | 120           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00039485111 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.35         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.13e+06      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000782     |
# |    value_loss           | 1.41e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.05         |
# |    ep_rew_mean          | -2.43e+03    |
# | time/                   |              |
# |    fps                  | 390          |
# |    iterations           | 24           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0015379894 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.34        |
# |    explained_variance   | 4.17e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.26e+06     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00253     |
# |    value_loss           | 1.49e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.08         |
# |    ep_rew_mean          | -2.34e+03    |
# | time/                   |              |
# |    fps                  | 389          |
# |    iterations           | 25           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0015751151 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.32        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.01e+06     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00377     |
# |    value_loss           | 1.5e+07      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.12          |
# |    ep_rew_mean          | -1.89e+03     |
# | time/                   |               |
# |    fps                  | 388           |
# |    iterations           | 26            |
# |    time_elapsed         | 137           |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 0.00097311835 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.39e+06      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.00155      |
# |    value_loss           | 1.31e+07      |
# -------------------------------------------
