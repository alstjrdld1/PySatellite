# %%
import gym
from libs.Environments.CircularOrbitEnv import *

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.env_checker import check_env

# %%
env = CircularOrbitEnv(
    satellite_num=500
)

check_env(env)

model = PPO("MlpPolicy", env, verbose=1,tensorboard_log="satellite")
model.learn(total_timesteps=1000000)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to satellite/PPO_9
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.29      |
# |    ep_rew_mean     | -9.94e+03 |
# | time/              |           |
# |    fps             | 66        |
# |    iterations      | 1         |
# |    time_elapsed    | 30        |
# |    total_timesteps | 2048      |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.42         |
# |    ep_rew_mean          | -9.58e+03    |
# | time/                   |              |
# |    fps                  | 65           |
# |    iterations           | 2            |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 9.313517e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.91        |
# |    explained_variance   | 1.07e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.72e+07     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000323    |
# |    value_loss           | 9.56e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.35          |
# |    ep_rew_mean          | -9.49e+03     |
# | time/                   |               |
# |    fps                  | 64            |
# |    iterations           | 3             |
# |    time_elapsed         | 94            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 1.2959354e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.7e+07       |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000408     |
# |    value_loss           | 9.56e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.46          |
# |    ep_rew_mean          | -9.88e+03     |
# | time/                   |               |
# |    fps                  | 64            |
# |    iterations           | 4             |
# |    time_elapsed         | 127           |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 1.4623511e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.68e+07      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.000435     |
# |    value_loss           | 9.61e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.45          |
# |    ep_rew_mean          | -9.84e+03     |
# | time/                   |               |
# |    fps                  | 64            |
# |    iterations           | 5             |
# |    time_elapsed         | 159           |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 1.1877855e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.61e+07      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000376     |
# |    value_loss           | 9.58e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.34         |
# |    ep_rew_mean          | -9.8e+03     |
# | time/                   |              |
# |    fps                  | 63           |
# |    iterations           | 6            |
# |    time_elapsed         | 193          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 1.205859e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.91        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.7e+07      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000409    |
# |    value_loss           | 9.59e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.32          |
# |    ep_rew_mean          | -9.57e+03     |
# | time/                   |               |
# |    fps                  | 63            |
# |    iterations           | 7             |
# |    time_elapsed         | 226           |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 1.0874646e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.69e+07      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000397     |
# |    value_loss           | 9.49e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.38          |
# |    ep_rew_mean          | -9.47e+03     |
# | time/                   |               |
# |    fps                  | 63            |
# |    iterations           | 8             |
# |    time_elapsed         | 259           |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 1.1931406e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.64e+07      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.000392     |
# |    value_loss           | 9.78e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.44          |
# |    ep_rew_mean          | -9.9e+03      |
# | time/                   |               |
# |    fps                  | 63            |
# |    iterations           | 9             |
# |    time_elapsed         | 292           |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 1.2200035e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.7e+07       |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000373     |
# |    value_loss           | 9.69e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.42          |
# |    ep_rew_mean          | -9.89e+03     |
# | time/                   |               |
# |    fps                  | 62            |
# |    iterations           | 10            |
# |    time_elapsed         | 325           |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 1.2998353e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.46e+07      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000453     |
# |    value_loss           | 9.34e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.46          |
# |    ep_rew_mean          | -9.45e+03     |
# | time/                   |               |
# |    fps                  | 62            |
# |    iterations           | 11            |
# |    time_elapsed         | 359           |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 1.1112716e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.73e+07      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000406     |
# |    value_loss           | 9.44e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.46          |
# |    ep_rew_mean          | -9.91e+03     |
# | time/                   |               |
# |    fps                  | 62            |
# |    iterations           | 12            |
# |    time_elapsed         | 392           |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 1.3087702e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.34e+07      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000402     |
# |    value_loss           | 9.57e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.45          |
# |    ep_rew_mean          | -9.76e+03     |
# | time/                   |               |
# |    fps                  | 62            |
# |    iterations           | 13            |
# |    time_elapsed         | 425           |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 1.6342674e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.71e+07      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000466     |
# |    value_loss           | 9.38e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.29          |
# |    ep_rew_mean          | -9.93e+03     |
# | time/                   |               |
# |    fps                  | 62            |
# |    iterations           | 14            |
# |    time_elapsed         | 458           |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 1.2048404e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.62e+07      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000421     |
# |    value_loss           | 9.25e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.42          |
# |    ep_rew_mean          | -9.9e+03      |
# | time/                   |               |
# |    fps                  | 62            |
# |    iterations           | 15            |
# |    time_elapsed         | 491           |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 1.0554795e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.67e+07      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000385     |
# |    value_loss           | 9.46e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.31         |
# |    ep_rew_mean          | -9.49e+03    |
# | time/                   |              |
# |    fps                  | 62           |
# |    iterations           | 16           |
# |    time_elapsed         | 525          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 1.135224e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.91        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.91e+07     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000433    |
# |    value_loss           | 9.26e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.41          |
# |    ep_rew_mean          | -9.5e+03      |
# | time/                   |               |
# |    fps                  | 62            |
# |    iterations           | 17            |
# |    time_elapsed         | 558           |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 1.2346718e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.63e+07      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000381     |
# |    value_loss           | 9.6e+07       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.33          |
# |    ep_rew_mean          | -9.82e+03     |
# | time/                   |               |
# |    fps                  | 62            |
# |    iterations           | 18            |
# |    time_elapsed         | 592           |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 1.0273943e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.65e+07      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.000377     |
# |    value_loss           | 9.44e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.34          |
# |    ep_rew_mean          | -9.6e+03      |
# | time/                   |               |
# |    fps                  | 62            |
# |    iterations           | 19            |
# |    time_elapsed         | 626           |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 1.0779477e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.73e+07      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000386     |
# |    value_loss           | 9.5e+07       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.27          |
# |    ep_rew_mean          | -9.55e+03     |
# | time/                   |               |
# |    fps                  | 62            |
# |    iterations           | 20            |
# |    time_elapsed         | 659           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 1.3001263e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.66e+07      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.0004       |
# |    value_loss           | 9.72e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.35          |
# |    ep_rew_mean          | -9.93e+03     |
# | time/                   |               |
# |    fps                  | 62            |
# |    iterations           | 21            |
# |    time_elapsed         | 693           |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 1.1656957e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.53e+07      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.000398     |
# |    value_loss           | 9.34e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.56          |
# |    ep_rew_mean          | -9.88e+03     |
# | time/                   |               |
# |    fps                  | 62            |
# |    iterations           | 22            |
# |    time_elapsed         | 726           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 1.1522206e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.57e+07      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000413     |
# |    value_loss           | 9.3e+07       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.4           |
# |    ep_rew_mean          | -9.92e+03     |
# | time/                   |               |
# |    fps                  | 62            |
# |    iterations           | 23            |
# |    time_elapsed         | 759           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 1.0657823e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.56e+07      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000373     |
# |    value_loss           | 9.37e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.43          |
# |    ep_rew_mean          | -9.91e+03     |
# | time/                   |               |
# |    fps                  | 62            |
# |    iterations           | 24            |
# |    time_elapsed         | 792           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 1.0293152e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.57e+07      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000378     |
# |    value_loss           | 9.65e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.25          |
# |    ep_rew_mean          | -9.92e+03     |
# | time/                   |               |
# |    fps                  | 62            |
# |    iterations           | 25            |
# |    time_elapsed         | 825           |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 1.1267839e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.37e+07      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.000387     |
# |    value_loss           | 9.49e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.36          |
# |    ep_rew_mean          | -9.5e+03      |
# | time/                   |               |
# |    fps                  | 62            |
# |    iterations           | 26            |
# |    time_elapsed         | 858           |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 1.2279197e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.59e+07      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000449     |
# |    value_loss           | 9.18e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.42          |
# |    ep_rew_mean          | -9.87e+03     |
# | time/                   |               |
# |    fps                  | 62            |
# |    iterations           | 27            |
# |    time_elapsed         | 891           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 1.1736993e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.97e+07      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000424     |
# |    value_loss           | 9.23e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.35          |
# |    ep_rew_mean          | -9.05e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 28            |
# |    time_elapsed         | 925           |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 1.1521042e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.61e+07      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.000403     |
# |    value_loss           | 9.23e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.39          |
# |    ep_rew_mean          | -9.53e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 29            |
# |    time_elapsed         | 958           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 1.2856617e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.97e+07      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000411     |
# |    value_loss           | 9.38e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.31          |
# |    ep_rew_mean          | -9.89e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 30            |
# |    time_elapsed         | 992           |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 1.3593817e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.07e+07      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.000405     |
# |    value_loss           | 9.39e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.28          |
# |    ep_rew_mean          | -9.84e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 31            |
# |    time_elapsed         | 1025          |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 1.1034426e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.5e+07       |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.000395     |
# |    value_loss           | 9.13e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.52         |
# |    ep_rew_mean          | -9.78e+03    |
# | time/                   |              |
# |    fps                  | 61           |
# |    iterations           | 32           |
# |    time_elapsed         | 1058         |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 9.876967e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.91        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.44e+07     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000378    |
# |    value_loss           | 9.14e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.29          |
# |    ep_rew_mean          | -9.89e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 33            |
# |    time_elapsed         | 1092          |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 1.2457313e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.31e+07      |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.000414     |
# |    value_loss           | 9.07e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.29          |
# |    ep_rew_mean          | -9.93e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 34            |
# |    time_elapsed         | 1126          |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 1.1264638e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.05e+07      |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.000386     |
# |    value_loss           | 9.16e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.42          |
# |    ep_rew_mean          | -9.45e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 35            |
# |    time_elapsed         | 1159          |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 1.1537632e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.57e+07      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.0004       |
# |    value_loss           | 9.27e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.39          |
# |    ep_rew_mean          | -9.52e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 36            |
# |    time_elapsed         | 1193          |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 1.2147939e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.98e+07      |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -0.000412     |
# |    value_loss           | 9.09e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.33          |
# |    ep_rew_mean          | -9.84e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 37            |
# |    time_elapsed         | 1226          |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 1.2090895e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.47e+07      |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000416     |
# |    value_loss           | 9.23e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.49          |
# |    ep_rew_mean          | -9.74e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 38            |
# |    time_elapsed         | 1260          |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 1.1360389e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.56e+07      |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.000433     |
# |    value_loss           | 9.12e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.37          |
# |    ep_rew_mean          | -9.89e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 39            |
# |    time_elapsed         | 1294          |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 1.0851654e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.33e+07      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000396     |
# |    value_loss           | 9.21e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.35         |
# |    ep_rew_mean          | -9.89e+03    |
# | time/                   |              |
# |    fps                  | 61           |
# |    iterations           | 40           |
# |    time_elapsed         | 1327         |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 1.192413e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.91        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.41e+07     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000459    |
# |    value_loss           | 8.96e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.4           |
# |    ep_rew_mean          | -9.92e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 41            |
# |    time_elapsed         | 1361          |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 1.2461387e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.56e+07      |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.000443     |
# |    value_loss           | 9.21e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.38          |
# |    ep_rew_mean          | -9.87e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 42            |
# |    time_elapsed         | 1394          |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 1.2190721e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.4e+07       |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000405     |
# |    value_loss           | 9.07e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.41          |
# |    ep_rew_mean          | -9.46e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 43            |
# |    time_elapsed         | 1428          |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 1.4739053e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.32e+07      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.000452     |
# |    value_loss           | 9.04e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.33          |
# |    ep_rew_mean          | -9.93e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 44            |
# |    time_elapsed         | 1462          |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 1.2206146e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.53e+07      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000422     |
# |    value_loss           | 9.07e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.23          |
# |    ep_rew_mean          | -9.95e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 45            |
# |    time_elapsed         | 1496          |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 1.1372613e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.51e+07      |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000399     |
# |    value_loss           | 9.1e+07       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.32          |
# |    ep_rew_mean          | -9.82e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 46            |
# |    time_elapsed         | 1529          |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 1.1880766e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.39e+07      |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000406     |
# |    value_loss           | 9.01e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.26          |
# |    ep_rew_mean          | -9.93e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 47            |
# |    time_elapsed         | 1563          |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 1.2419769e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.45e+07      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.000412     |
# |    value_loss           | 8.98e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.32          |
# |    ep_rew_mean          | -9.56e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 48            |
# |    time_elapsed         | 1597          |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 1.0665099e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.53e+07      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.0004       |
# |    value_loss           | 9.17e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.36          |
# |    ep_rew_mean          | -9.93e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 49            |
# |    time_elapsed         | 1630          |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 1.2402888e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.28e+07      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000416     |
# |    value_loss           | 9.04e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.39         |
# |    ep_rew_mean          | -9.89e+03    |
# | time/                   |              |
# |    fps                  | 61           |
# |    iterations           | 50           |
# |    time_elapsed         | 1664         |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 1.227425e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.91        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.47e+07     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00042     |
# |    value_loss           | 8.87e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.4           |
# |    ep_rew_mean          | -9.91e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 51            |
# |    time_elapsed         | 1697          |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 1.2566452e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.91         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.23e+07      |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.000418     |
# |    value_loss           | 9.09e+07      |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.45       |
# |    ep_rew_mean          | -9.59e+03  |
# | time/                   |            |
# |    fps                  | 61         |
# |    iterations           | 52         |
# |    time_elapsed         | 1731       |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 1.0402e-06 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.91      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.19e+07   |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.000361  |
# |    value_loss           | 8.99e+07   |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.31          |
# |    ep_rew_mean          | -9.92e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 53            |
# |    time_elapsed         | 1765          |
# |    total_timesteps      | 108544        |
# | train/                  |               |
# |    approx_kl            | 1.2012897e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# ...
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.9          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.34e+07      |
# |    n_updates            | 4710          |
# |    policy_gradient_loss | -0.000594     |
# |    value_loss           | 4.76e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.35         |
# |    ep_rew_mean          | -9.76e+03    |
# | time/                   |              |
# |    fps                  | 61           |
# |    iterations           | 473          |
# |    time_elapsed         | 15694        |
# |    total_timesteps      | 968704       |
# | train/                  |              |
# |    approx_kl            | 7.241819e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.9         |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.84e+07     |
# |    n_updates            | 4720         |
# |    policy_gradient_loss | -0.00058     |
# |    value_loss           | 4.88e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.41          |
# |    ep_rew_mean          | -9.59e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 474           |
# |    time_elapsed         | 15726         |
# |    total_timesteps      | 970752        |
# | train/                  |               |
# |    approx_kl            | 1.1622033e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.9          |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.92e+07      |
# |    n_updates            | 4730          |
# |    policy_gradient_loss | -0.000614     |
# |    value_loss           | 4.87e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.45          |
# |    ep_rew_mean          | -9.85e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 475           |
# |    time_elapsed         | 15758         |
# |    total_timesteps      | 972800        |
# | train/                  |               |
# |    approx_kl            | 6.7467627e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.9          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.32e+07      |
# |    n_updates            | 4740          |
# |    policy_gradient_loss | -0.00063      |
# |    value_loss           | 4.95e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.39          |
# |    ep_rew_mean          | -9.92e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 476           |
# |    time_elapsed         | 15790         |
# |    total_timesteps      | 974848        |
# | train/                  |               |
# |    approx_kl            | 5.0441595e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.9          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.74e+07      |
# |    n_updates            | 4750          |
# |    policy_gradient_loss | -0.000595     |
# |    value_loss           | 4.7e+07       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.38          |
# |    ep_rew_mean          | -9.89e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 477           |
# |    time_elapsed         | 15822         |
# |    total_timesteps      | 976896        |
# | train/                  |               |
# |    approx_kl            | 1.7039274e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.9          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.23e+07      |
# |    n_updates            | 4760          |
# |    policy_gradient_loss | -0.000699     |
# |    value_loss           | 4.71e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.37         |
# |    ep_rew_mean          | -9.93e+03    |
# | time/                   |              |
# |    fps                  | 61           |
# |    iterations           | 478          |
# |    time_elapsed         | 15855        |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 9.046838e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.9         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.87e+07     |
# |    n_updates            | 4770         |
# |    policy_gradient_loss | -0.000616    |
# |    value_loss           | 5.02e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.4          |
# |    ep_rew_mean          | -9.88e+03    |
# | time/                   |              |
# |    fps                  | 61           |
# |    iterations           | 479          |
# |    time_elapsed         | 15887        |
# |    total_timesteps      | 980992       |
# | train/                  |              |
# |    approx_kl            | 1.781914e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.9         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.35e+07     |
# |    n_updates            | 4780         |
# |    policy_gradient_loss | -0.000664    |
# |    value_loss           | 4.65e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.36          |
# |    ep_rew_mean          | -9.83e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 480           |
# |    time_elapsed         | 15919         |
# |    total_timesteps      | 983040        |
# | train/                  |               |
# |    approx_kl            | 1.0585965e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.9          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.03e+07      |
# |    n_updates            | 4790          |
# |    policy_gradient_loss | -0.00065      |
# |    value_loss           | 4.68e+07      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.41        |
# |    ep_rew_mean          | -9.53e+03   |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 481         |
# |    time_elapsed         | 15951       |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 7.60518e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.9        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.35e+07    |
# |    n_updates            | 4800        |
# |    policy_gradient_loss | -0.000582   |
# |    value_loss           | 4.84e+07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.28         |
# |    ep_rew_mean          | -9.8e+03     |
# | time/                   |              |
# |    fps                  | 61           |
# |    iterations           | 482          |
# |    time_elapsed         | 15983        |
# |    total_timesteps      | 987136       |
# | train/                  |              |
# |    approx_kl            | 6.909773e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.9         |
# |    explained_variance   | 2.38e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.31e+07     |
# |    n_updates            | 4810         |
# |    policy_gradient_loss | -0.000667    |
# |    value_loss           | 4.64e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.46          |
# |    ep_rew_mean          | -9.77e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 483           |
# |    time_elapsed         | 16015         |
# |    total_timesteps      | 989184        |
# | train/                  |               |
# |    approx_kl            | 6.0593593e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.9          |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.39e+07      |
# |    n_updates            | 4820          |
# |    policy_gradient_loss | -0.000536     |
# |    value_loss           | 4.93e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.37          |
# |    ep_rew_mean          | -9.59e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 484           |
# |    time_elapsed         | 16048         |
# |    total_timesteps      | 991232        |
# | train/                  |               |
# |    approx_kl            | 1.4885329e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.9          |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.27e+07      |
# |    n_updates            | 4830          |
# |    policy_gradient_loss | -0.000707     |
# |    value_loss           | 4.84e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.53          |
# |    ep_rew_mean          | -9.85e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 485           |
# |    time_elapsed         | 16080         |
# |    total_timesteps      | 993280        |
# | train/                  |               |
# |    approx_kl            | 1.1605269e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.9          |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.25e+07      |
# |    n_updates            | 4840          |
# |    policy_gradient_loss | -0.000609     |
# |    value_loss           | 4.66e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.39          |
# |    ep_rew_mean          | -9.78e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 486           |
# |    time_elapsed         | 16112         |
# |    total_timesteps      | 995328        |
# | train/                  |               |
# |    approx_kl            | 1.6911305e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.9          |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.24e+07      |
# |    n_updates            | 4850          |
# |    policy_gradient_loss | -0.000639     |
# |    value_loss           | 4.7e+07       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.43          |
# |    ep_rew_mean          | -9.8e+03      |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 487           |
# |    time_elapsed         | 16144         |
# |    total_timesteps      | 997376        |
# | train/                  |               |
# |    approx_kl            | 1.7243001e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.9          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.28e+07      |
# |    n_updates            | 4860          |
# |    policy_gradient_loss | -0.000548     |
# |    value_loss           | 4.56e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.43         |
# |    ep_rew_mean          | -9.57e+03    |
# | time/                   |              |
# |    fps                  | 61           |
# |    iterations           | 488          |
# |    time_elapsed         | 16176        |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 8.867937e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.9         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.26e+07     |
# |    n_updates            | 4870         |
# |    policy_gradient_loss | -0.000534    |
# |    value_loss           | 4.7e+07      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.26          |
# |    ep_rew_mean          | -9.86e+03     |
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 489           |
# |    time_elapsed         | 16208         |
# |    total_timesteps      | 1001472       |
# | train/                  |               |
# |    approx_kl            | 6.5714994e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.9          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.52e+07      |
# |    n_updates            | 4880          |
# |    policy_gradient_loss | -0.000547     |
# |    value_loss           | 4.77e+07      |
# -------------------------------------------
