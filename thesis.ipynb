# %%
from libs.Environments.thesis_env import *

env = ThesisEnv(
        satellite_num=12,
        orbit_alts=[600, 1000],
        ground_user_num=16
    )

while(True):
    # env.get_state(15)
    env.plot()
    # env.rotate(100)
# Out:
# d:\pySatellite\libs\Environments\CircularOrbit_2D.py:103: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x, y, 'ro', color = 'gray')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\pySatellite\thesis.ipynb Cell 1 in <cell line: 11>()
#       <a href='vscode-notebook-cell:/d%3A/pySatellite/thesis.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> env = ThesisEnv(
#       <a href='vscode-notebook-cell:/d%3A/pySatellite/thesis.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a>         satellite_num=12,
#       <a href='vscode-notebook-cell:/d%3A/pySatellite/thesis.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a>         orbit_alts=[600, 1000],
#       <a href='vscode-notebook-cell:/d%3A/pySatellite/thesis.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a>         ground_user_num=16
# ...
